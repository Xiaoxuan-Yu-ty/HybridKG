# %%
import pandas as pd
import numpy as np

# %%
knn_features = pd.read_csv("./data/kg_rule_features/knn_features.csv", sep='\t', index_col=0)
direct_features = pd.read_csv("./data/kg_rule_features/direct_features.csv", sep='\t', index_col=0)

# %%
features = np.concatenate((direct_features.to_numpy(),knn_features.to_numpy()), axis=1)
features.shape
np.savetxt('data/kg_rule_features/feature_matrix.csv',features, delimiter=',')
