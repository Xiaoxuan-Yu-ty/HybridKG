# %%
import torch
import pickle
import networkx as nx

import os
import sys
try:
    base_dir = os.path.dirname(os.path.abspath(__file__))
except NameError:
    base_dir = os.getcwd()
sys.path.append(os.path.dirname(base_dir))

from GateEmbeddingTask.encoders import RGATEncoder, HGTEncoder, get_encoder
from GateEmbeddingTask.train_utils import convert_to_hetero_data, build_data_dict

# %%
def load_graph(filepath:str):
    with open(filepath, 'rb') as f:
        G = pickle.load(f)
    print(f"Load graph with {G.number_of_nodes()} nodes and {G.number_of_edges()} edges")
    return G

# %%
network = load_graph("")
data, node_mappings = convert_to_hetero_data(network)
data = build_data_dict(data).to(device)

# %%
encoder = get_encoder(enc_type='rgat',
                                                                        data=data, 
                                                                        hidden_channels=128, 
                                                                        out_channels=64, 
                                                                        att_channels=32,
                                                                        num_layers=2, 
                                                                        dropout=0.1,
                                                                        aggr='sum',
                                                                        negative_slop=0.2,
                                                                        heads=1
                                                                        )
