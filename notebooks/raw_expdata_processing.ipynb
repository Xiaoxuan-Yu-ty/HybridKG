# %%
import pandas as pd
import numpy as np
import zipfile

# %% [markdown]
# ## ANMerge Data

# %%
# zip_path = '../data/ANMerge_TX_preprocessed.zip'
# extract_to = '../data/ANMerge'

# # Open and extract the zip file
# with zipfile.ZipFile(zip_path, 'r') as zip_ref:
#     zip_ref.extractall(extract_to)

# %%
an_gene = pd.read_csv("../data/ANMerge/ANMerge_gene_expression_normalized_under_90.csv", sep=r'[,\t\s]+', engine='python', index_col=0)
an_gene
# Out:
#              Visit  Month      Site Diagnosis     Sex   Age  APOE  MMSE  \
# DCR00001_1     1.0    0.0       DCR        AD  Female  80.0  E3E4  21.0
# DCR00004_1     1.0    0.0       DCR       MCI    Male  78.0  E4E4  27.0
# DCR00009_1     1.0    0.0       DCR       CTL  Female  69.0  E3E3  30.0
# DCR00013_1     1.0    0.0       DCR       CTL    Male  82.0  E3E3  30.0
# DCR00014_1     1.0    0.0       DCR       CTL  Female  75.0  E2E3  30.0
# ...            ...    ...       ...       ...     ...   ...   ...   ...
# TLSMCI607_1    1.0    0.0  Toulouse       MCI  Female  72.0  E3E3  29.0
# TLSMCI608_1    1.0    0.0  Toulouse       MCI    Male  73.0  E3E3  28.0
# TLSMCI609_1    1.0    0.0  Toulouse       MCI  Female  63.0  E3E3  28.0
# TLSMCI611_1    1.0    0.0  Toulouse       MCI  Female  78.0  E3E3  30.0
# TLSMCI612_1    1.0    0.0  Toulouse       MCI  Female  79.0  E3E3  28.0
#
#              Gexp_batch  0..gjSdbqnr.rUSTBI  ...  xu.S6OENiSSCDruXFc  \
# ...

# %%
an_metadata = an_gene[['Visit', 'Month', 'Site', 'Diagnosis', 'Sex', 'Age', 'APOE', 'MMSE',
       'Gexp_batch']]
an_exp = an_gene[list(an_gene.columns)[9:]]
#an_exp.to_csv("../data/ANMerge/ANMerge_exp.csv", sep='\t')
an_exp
# Out:
#              0..gjSdbqnr.rUSTBI  0.PRu.vXrqQjlN4p9I  00K3OeGXV631V5_6eA  \
# DCR00001_1             6.186378            7.319845            6.809282
# DCR00004_1             6.577102            7.568351            6.891144
# DCR00009_1             6.802756            7.363365            6.859408
# DCR00013_1             6.656712            7.076369            6.755748
# DCR00014_1             7.072468            7.182262            6.955473
# ...                         ...                 ...                 ...
# TLSMCI607_1            9.530581            8.861265            9.030972
# TLSMCI608_1            8.189603            8.830422            8.894175
# TLSMCI609_1            7.465088            7.654655            6.625375
# TLSMCI611_1            6.531374            7.379502            7.156618
# TLSMCI612_1            8.265589            9.378604            9.196883
#
#              00buPhOysV5Rpc5VF4  0106ep0.a1f3X61SF8  01BXNAw4H3SIpN6rXo  \
# ...

# %%
an_exp.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 691 entries, DCR00001_1 to TLSMCI612_1
# Columns: 5212 entries, 0..gjSdbqnr.rUSTBI to xz1S1tKD.sgqfTuesU
# dtypes: float64(5212)
# memory usage: 27.5+ MB

# %%
an_exp.describe()
# Out:
#        0..gjSdbqnr.rUSTBI  0.PRu.vXrqQjlN4p9I  00K3OeGXV631V5_6eA  \
# count          691.000000          691.000000          691.000000
# mean             7.951834            8.049107            7.784121
# std              1.032272            0.984549            1.056862
# min              5.970646            5.645431            5.458022
# 25%              7.007480            7.159544            6.811355
# 50%              7.849884            7.893146            8.144611
# 75%              8.917105            8.989891            8.769607
# max             10.032977            9.703974            9.374645
#
#        00buPhOysV5Rpc5VF4  0106ep0.a1f3X61SF8  01BXNAw4H3SIpN6rXo  \
# count          691.000000          691.000000          691.000000
# mean             7.711950            9.247522            9.908938
# std              1.125328            0.981661            1.156472
# min              5.145808            7.093563            5.371177
# ...

# %%
an_gene.columns
# Out:
# Index(['Visit', 'Month', 'Site', 'Diagnosis', 'Sex', 'Age', 'APOE', 'MMSE',
#        'Gexp_batch', '0..gjSdbqnr.rUSTBI',
#        ...
#        'xu.S6OENiSSCDruXFc', 'xu3n8ix_RpCpNPRKhc', 'xuBm5ckgidWRNTl.gQ',
#        'xuNOUeR1JerhIuIV7c', 'xud4v2r3nXECBua55o', 'xvHfVEL1fC35XJ7neU',
#        'xve7nuGHtAizelOmhE', 'xvrrv4q_nIDgJej.uU', 'xws9e3UChad1OnXmXY',
#        'xz1S1tKD.sgqfTuesU'],
#       dtype='str', length=5221)

# %%
an_gene['Diagnosis'].value_counts()
# Out:
# Diagnosis
# CTL    249
# AD     223
# MCI    219
# Name: count, dtype: int64

# %%
df = pd.read_csv("../data/ANMerge/removenas_expression_data.csv")#, sep=r'[,\t\s]+', engine='python')
df = df.set_index(keys=df['SYMBOL'])
df = df.drop(columns=['PROBEID','SYMBOL'])
df = df.T
df.to_csv("../data/ANMerge/ANMerge_exp_dropna.csv")
df
# Out:
# SYMBOL          GIMAP4     C1QBP    OCIAD2    ERICH1     MRTFA      DHPS  \
# DCR00001_1   10.624345  7.555940  6.186378  7.319845  6.368337  6.809282
# DCR00004_1   11.030950  7.752414  6.577102  7.568351  6.087313  6.891144
# DCR00009_1   10.804050  7.817921  6.802756  7.363365  6.228749  6.859408
# DCR00013_1   10.703988  7.636885  6.656712  7.076369  7.063700  6.755748
# DCR00014_1   10.819068  7.852751  7.072468  7.182262  6.547903  6.955473
# ...                ...       ...       ...       ...       ...       ...
# TLSMCI607_1  12.542553  9.669781  9.530581  8.861265  8.165198  9.030972
# TLSMCI608_1  12.224684  8.970987  8.189603  8.830422  8.744474  8.894175
# TLSMCI609_1  10.991729  7.848676  7.465088  7.654655  5.621634  6.625375
# TLSMCI611_1  10.668714  7.356087  6.531374  7.379502  6.759388  7.156618
# TLSMCI612_1  12.246394  9.246846  8.265589  9.378604  8.971024  9.196883
#
# SYMBOL           APH1A    TMEM154      CTSC        MBP  ...      PUS1  \
# ...

# %%
df = pd.read_csv("../data/ANMerge/processed_expression_data.csv")#, sep=r'[,\t\s]+', engine='python')

df['SYMBOL'] = df['SYMBOL'].fillna(df['PROBEID'])
df = df.set_index(keys=df['SYMBOL'])
df = df.drop(columns=['PROBEID','SYMBOL'])
df = df.T
df.to_csv("../data/ANMerge/ANMerge_exp_cleaned.csv")

# %%
df
# Out:
# SYMBOL          GIMAP4     C1QBP    OCIAD2    ERICH1     MRTFA      DHPS  \
# DCR00001_1   10.624345  7.555940  6.186378  7.319845  6.368337  6.809282
# DCR00004_1   11.030950  7.752414  6.577102  7.568351  6.087313  6.891144
# DCR00009_1   10.804050  7.817921  6.802756  7.363365  6.228749  6.859408
# DCR00013_1   10.703988  7.636885  6.656712  7.076369  7.063700  6.755748
# DCR00014_1   10.819068  7.852751  7.072468  7.182262  6.547903  6.955473
# ...                ...       ...       ...       ...       ...       ...
# TLSMCI607_1  12.542553  9.669781  9.530581  8.861265  8.165198  9.030972
# TLSMCI608_1  12.224684  8.970987  8.189603  8.830422  8.744474  8.894175
# TLSMCI609_1  10.991729  7.848676  7.465088  7.654655  5.621634  6.625375
# TLSMCI611_1  10.668714  7.356087  6.531374  7.379502  6.759388  7.156618
# TLSMCI612_1  12.246394  9.246846  8.265589  9.378604  8.971024  9.196883
#
# SYMBOL           APH1A    TMEM154      CTSC        MBP  ...      FNTA  \
# ...

# %%
adnmerge_proteins = set(df.columns)
len(adnmerge_proteins)
# Out:
# 5212

# %% [markdown]
# + Proteomics

# %%
an_proteomic = pd.read_csv("../data/ANMerge/ANMerge_Proteomics_under_90.csv", sep=r'[,\t\s]+', engine='python', index_col=0)
#an_proteomic = an_proteomic.dropna()
an_proteomic
# Out:
#              Visit  Month          Site Diagnosis     Sex   Age  APOE  \
# DCR00001_1     1.0    0.0           DCR        AD  Female  80.0  E3E4
# DCR00007_1     1.0    0.0           DCR        AD    Male  80.0  E3E4
# DCR00023_1     1.0    0.0           DCR        AD  Female  88.0  E3E3
# DCR00024_1     1.0    0.0           DCR        AD  Female  80.0  E3E4
# DCR00025_1     1.0    0.0           DCR        AD    Male  75.0  E4E4
# ...            ...    ...           ...       ...     ...   ...   ...
# THSMCI062_2    2.0   12.0  Thessaloniki        AD    Male  73.0  20.0
# THSMCI064_1    1.0    0.0  Thessaloniki       MCI    Male  80.0  E3E4
# THSMCI064_2    2.0   12.0  Thessaloniki        AD    Male  80.0  E3E4
# THSMCI065_1    1.0    0.0  Thessaloniki       MCI    Male  76.0  E3E3
# THSMCI065_2    2.0   12.0  Thessaloniki       MCI    Male  77.0  E3E3
#
#                 MMSE   P0C0L5  P03951  ...  P23396  Q86VB7  Q12884  Q8IXJ6  \
# ...

# %% [markdown]
# ## ADNI Data

# %%
adni_raw = pd.read_csv("../data/ADNI/adni_raw_data.csv", sep=r'[,\t\s]+', engine='python', index_col=0)
adni_raw
# Out:
#             11715100_at  11715101_s_at  11715102_x_at  11715103_x_at  \
# 116_S_1249        2.237          2.624          1.873          2.920
# 037_S_4410        2.294          2.416          1.884          2.668
# 006_S_4153        2.140          2.322          1.999          3.634
# 116_S_1232        2.062          2.500          1.851          3.632
# 099_S_4205        2.040          2.395          2.080          3.278
# ...                 ...            ...            ...            ...
# 009_S_2381        2.382          2.277          2.107          3.819
# 053_S_4557        2.497          2.466          2.137          3.541
# 073_S_4300        2.309          2.607          2.075          3.496
# 041_S_4014        2.302          2.569          2.147          4.037
# 007_S_0101        2.661          2.679          2.028          3.285
#
#             11715104_s_at  11715105_at  11715106_x_at  11715107_s_at  \
# ...

# %%
df_adni = pd.read_csv("../data/ADNI/processed_expression_data.csv", index_col=0)
df_adni
# Out:
#              H3C8  H3C8.1  H3C8.2  TNFAIP8L1  OTOP2  C17orf78  CTAGE6   F8A1  \
# Sample
# 116_S_1249  2.237   2.624   1.873      2.920  2.147     2.268   2.432  4.600
# 037_S_4410  2.294   2.416   1.884      2.668  2.156     2.130   2.270  4.547
# 006_S_4153  2.140   2.322   1.999      3.634  2.516     1.957   2.333  4.442
# 116_S_1232  2.062   2.500   1.851      3.632  2.283     2.347   2.258  4.608
# 099_S_4205  2.040   2.395   2.080      3.278  2.251     2.154   2.334  4.536
# ...           ...     ...     ...        ...    ...       ...     ...    ...
# 009_S_2381  2.382   2.277   2.107      3.819  2.588     2.201   2.531  4.455
# 053_S_4557  2.497   2.466   2.137      3.541  2.256     2.205   2.737  4.725
# 073_S_4300  2.309   2.607   2.075      3.496  2.098     2.161   2.439  4.981
# 041_S_4014  2.302   2.569   2.147      4.037  2.376     2.130   2.585  5.005
# 007_S_0101  2.661   2.679   2.028      3.285  2.333     2.074   2.854  5.009
#
# ...

# %%
df_clep = pd.read_csv("../CLEP_repeat/clep_resources/Datasets/ADNI/threshold/results/1/sample_scoring.tsv", sep='\t', index_col=0)
df_clep
# Out:
#             HIST1H3G  HIST1H3G.1  HIST1H3G.2  TNFAIP8L1  OTOP2  C17ORF78  \
# 116_S_1249         0           0           0          0      0         0
# 037_S_4410         0           0           0         -1      0         0
# 006_S_4153         0           0           0          0      0         0
# 116_S_1232         0           0           0          0      0         0
# 099_S_4205         0           0           0          0      0         0
# ...              ...         ...         ...        ...    ...       ...
# 009_S_2381         0           0           0          0      0         0
# 053_S_4557         0           0           0          0      0         0
# 073_S_4300         0           0           0          0      0         0
# 041_S_4014         0           0           0          0      0         0
# 007_S_0101         0           0           0          0      0         0
#
#             LINC01098  SAMD7  ARRDC5  C1ORF173  ...  H3F3AP4.2  RNA18S5  \
# ...

# %%
prs = ['CGB','CGB1', 'CGB2', 'CGB5', 'CGB7', 'CGB8']
for pr in prs:
    print(pr in df_clep.columns)
# Out:
# True
# True
# True
# True
# True
# True

# %% [markdown]
# ## Real original ADNI data
# 1. seperate metadata and expdata
# 2. explode expdata: rows with multiple gene symbols
# 3. drop NaN
# 4. Rename gene symbols with the same name by adding suffix

# %%
df_adni_raw = pd.read_csv("../data/ADNI/ADNI_Gene_Expression_Profile.csv", header=None, dtype=str, index_col=0)

# %%
df_adni_raw.head(10)
# Out:
#                         1         2           3           4           5    \
# 0
# Phase                   NaN       NaN      ADNIGO       ADNI2       ADNI2
# Visit                   NaN       NaN         m48         v03         v03
# SubjectID               NaN       NaN  116_S_1249  037_S_4410  006_S_4153
# 260/280                 NaN       NaN        2.05        2.07        2.04
# 260/230                 NaN       NaN        0.55        1.54         2.1
# RIN                     NaN       NaN         7.7         7.6         7.2
# Affy Plate              NaN       NaN           7           3           6
# YearofCollection        NaN       NaN        2011        2012        2011
# ProbeSet          LocusLink    Symbol         NaN         NaN         NaN
# 11715100_at         LOC8355  HIST1H3G       2.237       2.294        2.14
#
#                          6           7           8           9           10   \
# 0
# ...

# %%
subject_row = df_adni_raw.loc['SubjectID',3:]
subject_ids = subject_row.dropna().tolist()

# extract metadata
meta_rows = ["Phase", "Visit", "260/280", "260/230", "RIN", "Affy Plate","YearofCollection"]
metadata = (
    df_adni_raw[df_adni_raw.index.isin(meta_rows)]
    .iloc[:, 3:]
    .T
)

metadata.index = subject_ids
metadata.index.name = "SubjectID"

metadata
# Out:
# 0            Phase Visit 260/280 260/230  RIN Affy Plate YearofCollection
# SubjectID
# 116_S_1249   ADNI2   v03    2.07    1.54  7.6          3             2012
# 037_S_4410   ADNI2   v03    2.04     2.1  7.2          6             2011
# 006_S_4153  ADNIGO   m48    2.03    1.52  6.8          7             2011
# 116_S_1232   ADNI2   v03    2.01     1.6  7.9          9             2011
# 099_S_4205   ADNI2   v03    2.05    1.91    7          4             2012
# ...            ...   ...     ...     ...  ...        ...              ...
# 009_S_2381   ADNI2   v03    2.03    1.33  6.8          5             2012
# 053_S_4557   ADNI2   v03    2.11    0.27  6.2          3             2011
# 073_S_4300   ADNI2   v03    1.94    1.72  5.8          1             2011
# 041_S_4014   ADNI2   v06    2.06    1.35  6.7          4             2012
# 007_S_0101     NaN   NaN     NaN     NaN  NaN        NaN              NaN
#
# [744 rows x 7 columns]

# %%
subject_row = df_adni_raw.loc['SubjectID',3:]
subject_ids = subject_row.tolist()

# extract exp data
expdata = (
    df_adni_raw[df_adni_raw.index.str.contains("_at$")]
    .iloc[:, 1:]
)
expdata.columns = ['Symbol']+ subject_ids

# Explode the multiple gene symbols
# Split the string by ' || ', resulting in a list, then explode into rows
expdata['Symbol'] = expdata['Symbol'].str.split(' \|\| ')
expdata = expdata.explode('Symbol')

# %%
exp_dropna = expdata.dropna()
exp_dropna
# Out:
#                             Symbol 116_S_1249 037_S_4410 006_S_4153  \
# 0
# 11715100_at               HIST1H3G      2.237      2.294       2.14
# 11715101_s_at             HIST1H3G      2.624      2.416      2.322
# 11715102_x_at             HIST1H3G      1.873      1.884      1.999
# 11715103_x_at            TNFAIP8L1       2.92      2.668      3.634
# 11715104_s_at                OTOP2      2.147      2.156      2.516
# ...                            ...        ...        ...        ...
# AFFX-HUMRGE/M10098_5_at    RNA45S5       7.77       7.49      8.716
# AFFX-HUMRGE/M10098_M_at    RNA18S5     11.449     11.595     11.919
# AFFX-HUMRGE/M10098_M_at    RNA45S5     11.449     11.595     11.919
# AFFX-M27830_5_at           RNA28S5      4.416      4.746      5.519
# AFFX-M27830_5_at           RNA45S5      4.416      4.746      5.519
#
#                         116_S_1232 099_S_4205 007_S_4467 128_S_0205  \
# 0
# 11715100_at                  2.062       2.04      2.439      1.955
# ...

# %%
# Rename duplicated gene symbols
# Create a cumulative count for each symbol to generate the suffix
# 'cumcount' generates: 0, 1, 2... for occurrences of the same string
counts = exp_dropna.groupby('Symbol').cumcount()
# Append suffix only if the count is > 0
exp_dropna['Symbol'] = np.where(
    counts > 0, 
    exp_dropna['Symbol'] + '.' + counts.astype(int).astype(str), 
    exp_dropna['Symbol']
)
exp_dropna
# Out:
# /tmp/ipykernel_622803/3653314400.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exp_dropna['Symbol'] = np.where(
#                              Symbol 116_S_1249 037_S_4410 006_S_4153  \
# 0
# 11715100_at                HIST1H3G      2.237      2.294       2.14
# 11715101_s_at            HIST1H3G.1      2.624      2.416      2.322
# 11715102_x_at            HIST1H3G.2      1.873      1.884      1.999
# 11715103_x_at             TNFAIP8L1       2.92      2.668      3.634
# 11715104_s_at                 OTOP2      2.147      2.156      2.516
# ...                             ...        ...        ...        ...
# AFFX-HUMRGE/M10098_5_at   RNA45S5.1       7.77       7.49      8.716
# ...

# %%
exp = exp_dropna.set_index('Symbol')
symbol_meaning = exp.iloc[:,-1].to_dict()
exp = exp.iloc[:,:-1].T
exp
# Out:
# Symbol     HIST1H3G HIST1H3G.1 HIST1H3G.2 TNFAIP8L1  OTOP2 C17ORF78 CTAGE6  \
# 116_S_1249    2.237      2.624      1.873      2.92  2.147    2.268  2.432
# 037_S_4410    2.294      2.416      1.884     2.668  2.156     2.13   2.27
# 006_S_4153     2.14      2.322      1.999     3.634  2.516    1.957  2.333
# 116_S_1232    2.062        2.5      1.851     3.632  2.283    2.347  2.258
# 099_S_4205     2.04      2.395       2.08     3.278  2.251    2.154  2.334
# ...             ...        ...        ...       ...    ...      ...    ...
# 009_S_2381    2.382      2.277      2.107     3.819  2.588    2.201  2.531
# 053_S_4557    2.497      2.466      2.137     3.541  2.256    2.205  2.737
# 073_S_4300    2.309      2.607      2.075     3.496  2.098    2.161  2.439
# 041_S_4014    2.302      2.569      2.147     4.037  2.376     2.13  2.585
# 007_S_0101    2.661      2.679      2.028     3.285  2.333    2.074  2.854
#
# ...

# %%
exp.to_csv("../data/ADNI/adni_exp_realcleaned.csv")

# %%
import json

# Open a file in write mode ('w') and dump the dictionary
with open('../data/ADNI/adni_symbol_meaning.json', 'w', encoding='utf-8') as f:
    json.dump(symbol_meaning, f, indent=4, ensure_ascii=False)

# %%
pr_adni = set(exp_dropna['Symbol'].tolist())
print(len(pr_adni))
# Out:
# 50788

# %%
pr_clep = set(df_clep.columns)
len(pr_clep)
# Out:
# 49945

# %%
from matplotlib_venn import venn3, venn2
import matplotlib.pyplot as plt

def plot_venn(set1, set2, label1, label2, title=''):
    plt.figure(figsize=(10,6))
    venn = venn2((set1, set2), set_labels=(label1, label2))
    #plt.legend(handles=[red_patch, blue_patch, green_patch], loc='lower right', title="Legend")
    plt.title(title)
    plt.show()

# %%
plot_venn(pr_adni, pr_clep, 'My_ADNI', 'CLEP_ADNI')
